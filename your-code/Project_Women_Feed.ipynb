# %% [markdown]
# #Los blogs que se utilizaron para este análisis fueron:
# Business Insider (Negocios)
# Mashable (Tecnología y Social Media)
# Wired Science (Tecnología. Específicamente Ciencia)
# Yahoo news (Popular)

# %%
#Se importa la librería feedparser se utilizarán para leer y hacer el "parsing" del feed de distintos tipos de blogs.
#También se importa pandas para el trabajo con los data frames. 
import feedparser
import re
import pandas as pd

# %%
business = feedparser.parse('https://markets.businessinsider.com/rss/news')
business
# Out:
# {'feed': {'title': 'News Ticker - markets.businessinsider.com',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://markets.businessinsider.com/rss/news',
#    'value': 'News Ticker - markets.businessinsider.com'},
#   'subtitle': 'Get real-time stock quotes and charts, financial news, market data and portfolio management at markets.businessinsider.com',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://markets.businessinsider.com/rss/news',
#    'value': 'Get real-time stock quotes and charts, financial news, market data and portfolio management at markets.businessinsider.com'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://markets.businessinsider.com'}],
#   'link': 'https://markets.businessinsider.com',
#   'language': 'en-us',
#   'rights': 'finanzen.net GmbH',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
# ...

# %%
business.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
#Se buscan los keys del diccionario para conocer si existen títulos de las entradas. 
business.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'subtitle', 'subtitle_detail', 'links', 'link', 'language', 'rights', 'rights_detail', 'image'])

# %%
print(len(business['entries']))
# Out:
# 10

# %%
#Se realiza un loop para buscar los títulos de las entradas. 
titles = [business.entries[i].title for i in range(len(business.entries))]
print(titles)
# Out:
# ['ROSEN, A GLOBALLY RECOGNIZED LAW FIRM, Announces Investigation of Securities Claims Against Under Armour, Inc.; Encourages Investors with Losses in Excess of $100K to Contact the Firm - UA, UAA', 'Surge Energy Inc. Announces Third Quarter 2019 Results', 'Rockford Fosgate® Introduces Next Generation of Marine Speakers And Subwoofers featuring Color Optix™ RGB LED Lighting', 'Indonesia Stock Market May Snap Losing Streak', 'The Hanover Insurance Group Joins EndDD.org Sponsors', "NoodoeEV Partners With FreeVolt and LAC Supplier - New Partners Extend NoodoeEV's Reach Coast To Coast", 'Japanese Market Notably Higher', 'Hikvision showcased its latest innovative AI Cloud practices at CPSE 2019', 'ROSEN, A GLOBALLY RECOGNIZED LAW FIRM, Reminds iRobot Corporation Investors of Important Deadline in Securities Class Action; Encourages Investors with Losses in Excess of $500K to Contact the Firm', "Vanke Real Estate (Hong Kong) Company Limited -- Moody's assigns Baa2 to China Vanke's MTN drawd
# ...

# %%
import pandas as pd

# %%
#Se crea un data frame nuevo con una columna con los títulos de la entrada. 
df_business= pd.DataFrame(titles, columns= ['Title'])
df_business
# Out:
#                                                Title
# 0  ROSEN, A GLOBALLY RECOGNIZED LAW FIRM, Announc...
# 1  Surge Energy Inc. Announces Third Quarter 2019...
# 2  Rockford Fosgate® Introduces Next Generation o...
# 3      Indonesia Stock Market May Snap Losing Streak
# 4  The Hanover Insurance Group Joins EndDD.org Sp...
# 5  NoodoeEV Partners With FreeVolt and LAC Suppli...
# 6                     Japanese Market Notably Higher
# 7  Hikvision showcased its latest innovative AI C...
# 8  ROSEN, A GLOBALLY RECOGNIZED LAW FIRM, Reminds...
# 9  Vanke Real Estate (Hong Kong) Company Limited ...

# %%
#Se crea una columna nueva para clasificar la información y determinar si el título tiene la(s) palabra(s): Women, Girl o Woman. Se integró .lowe() para que reconociera las minúsculas y además una expresión para que identificara la palabras. El resultado en la columna es un boleano: True or False.
df_business['Word_Appears'] = df_business.Title.str.lower().str.contains('women|girl|woman')
df_business
# Out:
#                                                Title  Word_Appears
# 0  ROSEN, A GLOBALLY RECOGNIZED LAW FIRM, Announc...         False
# 1  Surge Energy Inc. Announces Third Quarter 2019...         False
# 2  Rockford Fosgate® Introduces Next Generation o...         False
# 3      Indonesia Stock Market May Snap Losing Streak         False
# 4  The Hanover Insurance Group Joins EndDD.org Sp...         False
# 5  NoodoeEV Partners With FreeVolt and LAC Suppli...         False
# 6                     Japanese Market Notably Higher         False
# 7  Hikvision showcased its latest innovative AI C...         False
# 8  ROSEN, A GLOBALLY RECOGNIZED LAW FIRM, Reminds...         False
# 9  Vanke Real Estate (Hong Kong) Company Limited ...         False

# %% [markdown]
# #A partir de este momento el proceso se repite con los blogs Mashable, Wired y Yahoo. Se recopila la información y se limpia el data set.

# %%
mashable = feedparser.parse('http://feeds.mashable.com/Mashable')
mashable
# Out:
# {'feed': {'title': 'Mashable',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.mashable.com/Mashable',
#    'value': 'Mashable'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://mashable.com/?utm_campaign=Mash-Prod-RSS-Feedburner-All-Partial&utm_cid=Mash-Prod-RSS-Feedburner-All-Partial'},
#    {'rel': 'self',
#     'type': 'application/rss+xml',
#     'href': 'http://feeds.mashable.com/Mashable'},
#    {'rel': 'hub',
#     'href': 'http://pubsubhubbub.appspot.com/',
#     'type': 'text/html'}],
#   'link': 'https://mashable.com/?utm_campaign=Mash-Prod-RSS-Feedburner-All-Partial&utm_cid=Mash-Prod-RSS-Feedburner-All-Partial',
# ...

# %%
mashable.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
mashable.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'href', 'snf_logo', 'sy_updateperiod', 'sy_updatefrequency', 'language', 'published', 'published_parsed', 'updated', 'updated_parsed', 'generator_detail', 'generator', 'xhtml_meta', 'feedburner_info', 'thespringbox_skin', 'feedburner_feedflare', 'info', 'info_detail'])

# %%
print(len(mashable['entries']))
# Out:
# 30

# %%
titlesTwo = [mashable.entries[i].title for i in range(len(mashable.entries))]
print(titlesTwo)
# Out:
# ["When exactly is the end of the f***ing world in &#8216;The End of the F***ing World'?", "'The End of the F***ing World' stars test their knowledge of legendary TV anti-heroes", "Ex-Facebook head says company 'profits partly by amplifying lies'", 'Chrissy Teigen is now a YouTuber', "Boomers getting mad at everyone saying 'OK Boomer' makes it even funnier", 'Worst reasons for Trump to quit the Paris climate pact, unranked', 'Bob Iger says to expect a &#8216;slowdown&#8217; of Disney-released &#8216;Star Wars&#8217; films', 'Apple plans to donate $2.5 billion to fight California housing crisis', "Jessica Chastain praises Joaquin Phoenix's work in 'The Joker'", 'This device opens your curtains with your voice &#8212;&#160;Future Blink', '8chan reappears with new name, request for users not to engage in illegal activity', "'For All Mankind' never slows down enough to serve its clever premise", "Everyone's laughing at Facebook's boomer rebrand to FACEBOOK", 'Why Facebook just changed its
# ...

# %%
df_mashable = pd.DataFrame(titlesTwo, columns= ['Title'])
df_mashable
# Out:
#                                                 Title
# 0   When exactly is the end of the f***ing world i...
# 1   'The End of the F***ing World' stars test thei...
# 2   Ex-Facebook head says company 'profits partly ...
# 3                    Chrissy Teigen is now a YouTuber
# 4   Boomers getting mad at everyone saying 'OK Boo...
# 5   Worst reasons for Trump to quit the Paris clim...
# 6   Bob Iger says to expect a &#8216;slowdown&#821...
# 7   Apple plans to donate $2.5 billion to fight Ca...
# 8   Jessica Chastain praises Joaquin Phoenix's wor...
# 9   This device opens your curtains with your voic...
# 10  8chan reappears with new name, request for use...
# 11  'For All Mankind' never slows down enough to s...
# 12  Everyone's laughing at Facebook's boomer rebra...
# 13         Why Facebook just changed its company logo
# 14  Man accidentally buys 1000 hens from online au...
# 15  Report claims Apple is teaming with Valve to d...
# ...

# %%
df_mashable['Title'][17]

df_mashable['Word_Appears'] = df_mashable.Title.str.lower().str.contains('women|girl|woman')
df_mashable
# Out:
#                                                 Title  Word_Appears
# 0   When exactly is the end of the f***ing world i...         False
# 1   'The End of the F***ing World' stars test thei...         False
# 2   Ex-Facebook head says company 'profits partly ...         False
# 3                    Chrissy Teigen is now a YouTuber         False
# 4   Boomers getting mad at everyone saying 'OK Boo...         False
# 5   Worst reasons for Trump to quit the Paris clim...         False
# 6   Bob Iger says to expect a &#8216;slowdown&#821...         False
# 7   Apple plans to donate $2.5 billion to fight Ca...         False
# 8   Jessica Chastain praises Joaquin Phoenix's wor...         False
# 9   This device opens your curtains with your voic...         False
# 10  8chan reappears with new name, request for use...         False
# 11  'For All Mankind' never slows down enough to s...         False
# 12  Everyone's laughing at Facebook's boomer rebra...         False
# ...

# %%
wired = feedparser.parse('https://www.wired.com/feed/category/science/latest/rss')
wired
# Out:
# {'feed': {'title': 'Science Latest',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.wired.com/feed/category/science/latest/rss',
#    'value': 'Science Latest'},
#   'subtitle': 'Channel Description',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.wired.com/feed/category/science/latest/rss',
#    'value': 'Channel Description'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.wired.com/category/science/latest'},
#    {'href': 'https://www.wired.com/feed/category/science/latest/rss',
#     'rel': 'self',
#     'type': 'application/atom+xml'}],
#   'link': 'https://www.wired.com/category/science/latest',
#   'rights': '© Condé Nast 2019',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.wired.com/feed/category/science/latest/rss',
#    'value': '© Condé Nast 2019'},
#   'language': 'en',
# ...

# %%
wired.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
wired.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'subtitle', 'subtitle_detail', 'links', 'link', 'rights', 'rights_detail', 'language', 'updated', 'updated_parsed'])

# %%
print(len(wired['entries']))
# Out:
# 20

# %%
titlesThree = [wired.entries[i].title for i in range(len(wired.entries))]
print(titlesThree)
# Out:
# ['Trump Begins Paris Accord Exit, Devices Hacked With Lasers, and More News', "Trump Can Now Exit the Paris Accord. It's Still a Bad Idea", 'Where Do Hippos Wander? An Aquatic Mystery, Solved', 'Here’s What Happens When You Leave Weed Up Your Nose for 18 Years', 'Cosmic Triangles Open a Window to the Origin of Time', 'These Rats Drive Tiny Cars—for Science', 'Wildfire Chasers Are the New Tornado Chasers', 'Your Brain Cleans Itself, This Jet Lands Itself, and More News', 'Scientists Now Know How Sleep Cleans Toxins From the Brain', 'How Measles Leaves Kids Exposed to Other Diseases', 'The Delicate Art—and Evolving Science—of Wildfire Evacuations', 'NASA Is Getting Serious About an Interstellar Mission', 'Fly Me to the Moon … With Elephants\\!', "How Lasers Work, According to the World's Top Expert", 'Ants Never Get Stuck in Traffic Jams. Here’s Why', 'Prepping Bees for Mars, New Google Shortcuts, and More News', 'Shifting Winds and the Changing Shape of California Fires', 'Trans Athle
# ...

# %%
df_wired = pd.DataFrame(titlesThree, columns= ['Title'])
df_wired
# Out:
#                                                 Title
# 0   Trump Begins Paris Accord Exit, Devices Hacked...
# 1   Trump Can Now Exit the Paris Accord. It's Stil...
# 2   Where Do Hippos Wander? An Aquatic Mystery, So...
# 3   Here’s What Happens When You Leave Weed Up You...
# 4   Cosmic Triangles Open a Window to the Origin o...
# 5              These Rats Drive Tiny Cars—for Science
# 6        Wildfire Chasers Are the New Tornado Chasers
# 7   Your Brain Cleans Itself, This Jet Lands Itsel...
# 8   Scientists Now Know How Sleep Cleans Toxins Fr...
# 9   How Measles Leaves Kids Exposed to Other Diseases
# 10  The Delicate Art—and Evolving Science—of Wildf...
# 11  NASA Is Getting Serious About an Interstellar ...
# 12              Fly Me to the Moon … With Elephants\!
# 13  How Lasers Work, According to the World's Top ...
# 14   Ants Never Get Stuck in Traffic Jams. Here’s Why
# 15  Prepping Bees for Mars, New Google Shortcuts, ...
# ...

# %%
df_wired['Word_Appears'] = df_wired.Title.str.lower().str.contains('women|girl|woman')
df_wired
# Out:
#                                                 Title  Word_Appears
# 0   Trump Begins Paris Accord Exit, Devices Hacked...         False
# 1   Trump Can Now Exit the Paris Accord. It's Stil...         False
# 2   Where Do Hippos Wander? An Aquatic Mystery, So...         False
# 3   Here’s What Happens When You Leave Weed Up You...         False
# 4   Cosmic Triangles Open a Window to the Origin o...         False
# 5              These Rats Drive Tiny Cars—for Science         False
# 6        Wildfire Chasers Are the New Tornado Chasers         False
# 7   Your Brain Cleans Itself, This Jet Lands Itsel...         False
# 8   Scientists Now Know How Sleep Cleans Toxins Fr...         False
# 9   How Measles Leaves Kids Exposed to Other Diseases         False
# 10  The Delicate Art—and Evolving Science—of Wildf...         False
# 11  NASA Is Getting Serious About an Interstellar ...         False
# 12              Fly Me to the Moon … With Elephants\!         False
# ...

# %%
yahoo = feedparser.parse('https://www.yahoo.com/news/rss')
yahoo
# Out:
# {'feed': {'title': 'Yahoo News - Latest News & Headlines',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.yahoo.com/news/rss',
#    'value': 'Yahoo News - Latest News & Headlines'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.yahoo.com/news'}],
#   'link': 'https://www.yahoo.com/news',
#   'subtitle': 'The latest news and headlines from Yahoo! News. Get breaking news stories and in-depth coverage with videos and photos.',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.yahoo.com/news/rss',
#    'value': 'The latest news and headlines from Yahoo! News. Get breaking news stories and in-depth coverage with videos and photos.'},
#   'language': 'en-US',
#   'rights': 'Copyright (c) 2019 Yahoo! Inc. All rights reserved',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.yahoo.com/news/rss',
# ...

# %%
yahoo.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
yahoo.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'language', 'rights', 'rights_detail', 'published', 'published_parsed', 'ttl', 'image'])

# %%
print(len(yahoo['entries']))
# Out:
# 50

# %%
titlesFour = [yahoo.entries[i].title for i in range(len(yahoo.entries))]
print(titlesFour)
# Out:
# ['California illegal pot seizures top $1.5 billion in value', '&#39;I have the real polls&#39;: Trump calls Fox News polls &#39;lousy&#39; after survey finds 49% support impeachment', 'A woman was impaled by a metal pole while riding in the passenger seat of a car, but somehow miraculously survived', 'Brazil&#39;s Bolsonaro says &#39;worst is yet to come&#39; on oil spill', 'U.S. targets Iranian top leader&#39;s inner circle with new sanctions', 'Here&#39;s the Real 2020 Ford Bronco in Off-Road-Racing Form', 'China is reportedly sending men to sleep in the same beds as Uighur Muslim women', 'US white supremacist arrested hours before far-right conference in Norway', 'Confirmed: China Still Insists It Won&#39;t Use Nuclear Weapons First in a War', 'Assistant scoutmaster charged with sexually abusing boy, 12', 'Ukraine is reportedly firing the prosecutor who led the investigation into Hunter Biden&#39;s firm', 'Persons of interest identified in deaths of New Hampshire couple found buri
# ...

# %%
df_yahoo = pd.DataFrame(titlesFour, columns= ['Title'])
df_yahoo
# Out:
#                                                 Title
# 0   California illegal pot seizures top $1.5 billi...
# 1   &#39;I have the real polls&#39;: Trump calls F...
# 2   A woman was impaled by a metal pole while ridi...
# 3   Brazil&#39;s Bolsonaro says &#39;worst is yet ...
# 4   U.S. targets Iranian top leader&#39;s inner ci...
# 5   Here&#39;s the Real 2020 Ford Bronco in Off-Ro...
# 6   China is reportedly sending men to sleep in th...
# 7   US white supremacist arrested hours before far...
# 8   Confirmed: China Still Insists It Won&#39;t Us...
# 9   Assistant scoutmaster charged with sexually ab...
# 10  Ukraine is reportedly firing the prosecutor wh...
# 11  Persons of interest identified in deaths of Ne...
# 12  ‘Not our mission’: private fire crews protect ...
# 13  Iran frets as anti-government protests take ho...
# 14  Every Mid-Engined Sports Car—Including a Few Y...
# 15  Mexico&#39;s drug gangs churning out deadly fe...
# ...

# %%
df_yahoo['Word_Appears'] = df_yahoo.Title.str.lower().str.contains('women|girl|woman')
df_yahoo
# Out:
#                                                 Title  Word_Appears
# 0   California illegal pot seizures top $1.5 billi...         False
# 1   &#39;I have the real polls&#39;: Trump calls F...         False
# 2   A woman was impaled by a metal pole while ridi...          True
# 3   Brazil&#39;s Bolsonaro says &#39;worst is yet ...         False
# 4   U.S. targets Iranian top leader&#39;s inner ci...         False
# 5   Here&#39;s the Real 2020 Ford Bronco in Off-Ro...         False
# 6   China is reportedly sending men to sleep in th...          True
# 7   US white supremacist arrested hours before far...         False
# 8   Confirmed: China Still Insists It Won&#39;t Us...         False
# 9   Assistant scoutmaster charged with sexually ab...         False
# 10  Ukraine is reportedly firing the prosecutor wh...         False
# 11  Persons of interest identified in deaths of Ne...         False
# 12  ‘Not our mission’: private fire crews protect ...         False
# ...

# %%
#Se hace un data frame concatenado con todos los data frames realizados. El arreglo es el primer argumento. 
df_Feed = pd.concat([df_business, df_mashable, df_wired, df_yahoo])
df_Feed
# Out:
#                                                 Title  Word_Appears
# 0   ROSEN, A GLOBALLY RECOGNIZED LAW FIRM, Announc...         False
# 1   Surge Energy Inc. Announces Third Quarter 2019...         False
# 2   Rockford Fosgate® Introduces Next Generation o...         False
# 3       Indonesia Stock Market May Snap Losing Streak         False
# 4   The Hanover Insurance Group Joins EndDD.org Sp...         False
# ..                                                ...           ...
# 45  NASA probe provides insight on solar system&#3...         False
# 46  NYPD commissioner&#39;s exit: &#39;Right time&...         False
# 47  PG&E CEO Causes Outrage After Saying Strugglin...         False
# 48  Russia Held Up an Ailing American Military Att...         False
# 49  Bloody Tijuana: a week in the life of Mexico&#...         False
#
# [110 rows x 2 columns]

# %%
#Del data frame consolidado, se obtiene el número total de "True" (si en los títulos aparece la(s) palabra(s) Women, Girl, Woman). Al ser pocos resultados, busqué la categoría (o tema) directamente en el medio y con el título.
len(df_Feed[df_Feed.Word_Appears == True])
# Out:
# 4

# %%
#Se exporta la información al archivo .csv para poder manipularlo y concatenarlo en el file de la API. 
df_Feed.to_csv('Project_Women_Feed.csv', index=False)
